# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('collegePlace.csv')

# %%
df.head()
# Out:
#    Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0   22    Male  Electronics And Communication            1     8       1
# 1   21  Female               Computer Science            0     7       1
# 2   22  Female         Information Technology            1     6       0
# 3   21    Male         Information Technology            0     8       0
# 4   22    Male                     Mechanical            0     8       1
#
#    HistoryOfBacklogs  PlacedOrNot
# 0                  1            1
# 1                  1            1
# 2                  0            1
# 3                  1            1
# 4                  0            1

# %%
df.head(100)
# Out:
#     Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0    22    Male  Electronics And Communication            1     8       1
# 1    21  Female               Computer Science            0     7       1
# 2    22  Female         Information Technology            1     6       0
# 3    21    Male         Information Technology            0     8       0
# 4    22    Male                     Mechanical            0     8       1
# ..  ...     ...                            ...          ...   ...     ...
# 95   22    Male               Computer Science            1     8       0
# 96   21    Male               Computer Science            2     7       0
# 97   22    Male         Information Technology            0     8       0
# 98   22  Female         Information Technology            0     7       0
# 99   21    Male                     Mechanical            0     7       0
#
#     HistoryOfBacklogs  PlacedOrNot
# 0                   1            1
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (2966, 8)

# %%
df['Gender'].replace({'Male':0,'Female':1},inplace=True)

# %%
df.head(10)
# Out:
#    Age  Gender                         Stream  Internships  CGPA  Hostel  \
# 0   22       0  Electronics And Communication            1     8       1
# 1   21       1               Computer Science            0     7       1
# 2   22       1         Information Technology            1     6       0
# 3   21       0         Information Technology            0     8       0
# 4   22       0                     Mechanical            0     8       1
# 5   22       0  Electronics And Communication            0     6       0
# 6   21       0               Computer Science            0     7       0
# 7   21       0         Information Technology            1     7       0
# 8   21       0               Computer Science            2     6       0
# 9   21       1               Computer Science            1     6       1
#
#    HistoryOfBacklogs  PlacedOrNot
# 0                  1            1
# 1                  1            1
# 2                  0            1
# ...

# %%
df['Stream'].unique()
# Out:
# array(['Electronics And Communication', 'Computer Science',
#        'Information Technology', 'Mechanical', 'Electrical', 'Civil'],
#       dtype=object)

# %%
df['Stream'].replace({'Electronics And Communication':0, 'Computer Science':1, 'Information Technology':2, 'Mechanical':3, 
                      'Electrical':4, 'Civil':5
                     },inplace=True)

# %%
df.head(10)
# Out:
#    Age  Gender  Stream  Internships  CGPA  Training  HistoryOfBacklogs  \
# 0   22       0       0            1     8         1                  1
# 1   21       1       1            0     7         1                  1
# 2   22       1       2            1     6         0                  0
# 3   21       0       2            0     8         0                  1
# 4   22       0       3            0     8         1                  0
# 5   22       0       0            0     6         0                  0
# 6   21       0       1            0     7         0                  1
# 7   21       0       2            1     7         0                  0
# 8   21       0       1            2     6         0                  0
# 9   21       1       1            1     6         1                  0
#
#    PlacedOrNot
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# 5            0
# 6            0
# 7            0
# 8            1
# 9            0

# %%
df.rename(columns = {'Hostel':'Training'}, inplace = True)

# %%
df.head(10)
# Out:
#    Age  Gender  Stream  Internships  CGPA  Training  HistoryOfBacklogs  \
# 0   22       0       0            1     8         1                  1
# 1   21       1       1            0     7         1                  1
# 2   22       1       2            1     6         0                  0
# 3   21       0       2            0     8         0                  1
# 4   22       0       3            0     8         1                  0
# 5   22       0       0            0     6         0                  0
# 6   21       0       1            0     7         0                  1
# 7   21       0       2            1     7         0                  0
# 8   21       0       1            2     6         0                  0
# 9   21       1       1            1     6         1                  0
#
#    PlacedOrNot
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# 5            0
# 6            0
# 7            0
# 8            1
# 9            0

# %%
df.isnull().sum()
# Out:
# Age                  0
# Gender               0
# Stream               0
# Internships          0
# CGPA                 0
# Training             0
# HistoryOfBacklogs    0
# PlacedOrNot          0
# dtype: int64

# %%
age=df['Age']
gender=df['Gender']
stream=df['Stream']
internship=df['Internships']
cgpa=df['CGPA']
training=df['Training']
backlogs=df['HistoryOfBacklogs']
p=df['PlacedOrNot']

# %%
plt.scatter(age,p)

# %%
Y=df['PlacedOrNot']
X=df.drop(['PlacedOrNot'],axis=1)

# %%
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2961    0
# 2962    0
# 2963    0
# 2964    0
# 2965    1
# Name: PlacedOrNot, Length: 2966, dtype: int64

# %%
X
# Out:
#       Age  Gender  Stream  Internships  CGPA  Training  HistoryOfBacklogs
# 0      22       0       0            1     8         1                  1
# 1      21       1       1            0     7         1                  1
# 2      22       1       2            1     6         0                  0
# 3      21       0       2            0     8         0                  1
# 4      22       0       3            0     8         1                  0
# ...   ...     ...     ...          ...   ...       ...                ...
# 2961   23       0       2            0     7         0                  0
# 2962   23       0       3            1     7         1                  0
# 2963   22       0       2            1     7         0                  0
# 2964   22       0       1            1     7         0                  0
# 2965   23       0       5            0     8         0                  0
#
# [2966 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, train_size=0.80, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logreg=LogisticRegression()

logreg.fit(X_train,Y_train)
Y_predict = logreg.predict(X_test)
print(logreg.score(X_test, Y_test))
# Out:
# 0.7621722846441947

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, Y_train)
Y_pred=rf.predict(X_test);

print("Accuracy % = " , metrics.accuracy_score(Y_test,Y_pred) * 100)
# Out:
# Accuracy % =  87.54208754208754

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, Y_train)
Y_pred=knn.predict(X_test)
print("Accuracy % = " , metrics.accuracy_score(Y_test,Y_pred) * 100)
# Out:
# Accuracy % =  84.84848484848484

# %%
#Manual Data Set Format = ['Age', 'Gender', 'Streams', 'Internships', 'CGPA', 'Trainings', 'HistoryOfBacklogs']
import numpy as np
features=np.array([['22','0','0','1','8','0','1']])
p=rf.predict(features)
print(p)
# Out:
# [1]
# C:\Users\wasee\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import pickle
fName = 'Logistic_Regression.pkl'
pickle.dump(logreg,open(fName,'wb'))

# %%
import pickle
fName = 'Random_Forest.pkl'
pickle.dump(rf,open(fName,'wb'))

# %%
import pickle
fName = 'KNN.pkl'
pickle.dump(knn,open(fName,'wb'))
